# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import warnings 
warnings.filterwarnings('ignore')

# %%
df=pd.read_csv('autos_dataset - autos_dataset.csv')
df
# Out:
#      symboling normalized-losses         make fuel-type aspiration  \
# 0            3                 ?  alfa-romero       gas        std
# 1            3                 ?  alfa-romero       gas        std
# 2            1                 ?  alfa-romero       gas        std
# 3            2               164         audi       gas        std
# 4            2               164         audi       gas        std
# ..         ...               ...          ...       ...        ...
# 200         -1                95        volvo       gas        std
# 201         -1                95        volvo       gas      turbo
# 202         -1                95        volvo       gas        std
# 203         -1                95        volvo    diesel      turbo
# 204         -1                95        volvo       gas      turbo
#
#     num-of-doors   body-style drive-wheels engine-location  wheel-base  ...  \
# 0            two  convertible          rwd           front        88.6  ...
# ...

# %%
df.describe()
# Out:
#         symboling  wheel-base      length       width      height  \
# count  205.000000  205.000000  205.000000  205.000000  205.000000
# mean     0.834146   98.756585  174.049268   65.907805   53.724878
# std      1.245307    6.021776   12.337289    2.145204    2.443522
# min     -2.000000   86.600000  141.100000   60.300000   47.800000
# 25%      0.000000   94.500000  166.300000   64.100000   52.000000
# 50%      1.000000   97.000000  173.200000   65.500000   54.100000
# 75%      2.000000  102.400000  183.100000   66.900000   55.500000
# max      3.000000  120.900000  208.100000   72.300000   59.800000
#
#        curb-weight  engine-size  compression-ratio    city-mpg  highway-mpg
# count   205.000000   205.000000         205.000000  205.000000   205.000000
# mean   2555.565854   126.907317          10.142537   25.219512    30.751220
# std     520.680204    41.642693           3.972040    6.542142     6.886443
# ...

# %%
df.columns
# Out:
# Index(['symboling', 'normalized-losses', 'make', 'fuel-type', 'aspiration',
#        'num-of-doors', 'body-style', 'drive-wheels', 'engine-location',
#        'wheel-base', 'length', 'width', 'height', 'curb-weight', 'engine-type',
#        'num-of-cylinders', 'engine-size', 'fuel-system', 'bore', 'stroke',
#        'compression-ratio', 'horsepower', 'peak-rpm', 'city-mpg',
#        'highway-mpg', 'price'],
#       dtype='object')

# %%
df.isna().sum()
# Out:
# symboling            0
# normalized-losses    0
# make                 0
# fuel-type            0
# aspiration           0
# num-of-doors         0
# body-style           0
# drive-wheels         0
# engine-location      0
# wheel-base           0
# length               0
# width                0
# height               0
# curb-weight          0
# engine-type          0
# num-of-cylinders     0
# engine-size          0
# fuel-system          0
# bore                 0
# stroke               0
# compression-ratio    0
# horsepower           0
# peak-rpm             0
# city-mpg             0
# highway-mpg          0
# price                0
# dtype: int64

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 205 entries, 0 to 204
# Data columns (total 26 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   symboling          205 non-null    int64
#  1   normalized-losses  205 non-null    object
#  2   make               205 non-null    object
#  3   fuel-type          205 non-null    object
#  4   aspiration         205 non-null    object
#  5   num-of-doors       205 non-null    object
#  6   body-style         205 non-null    object
#  7   drive-wheels       205 non-null    object
#  8   engine-location    205 non-null    object
#  9   wheel-base         205 non-null    float64
#  10  length             205 non-null    float64
#  11  width              205 non-null    float64
#  12  height             205 non-null    float64
#  13  curb-weight        205 non-null    int64
#  14  engine-type        205 non-null    object
#  15  num-of-cylinders   205 non-null    object
# ...

# %% [markdown]
# ## normalized-losses

# %%
df['normalized-losses'].value_counts()
# Out:
# normalized-losses
# ?      41
# 161    11
# 91      8
# 150     7
# 134     6
# 128     6
# 104     6
# 85      5
# 94      5
# 65      5
# 102     5
# 74      5
# 168     5
# 103     5
# 95      5
# 106     4
# 93      4
# 118     4
# 148     4
# 122     4
# 83      3
# 125     3
# 154     3
# 115     3
# 137     3
# 101     3
# 119     2
# 87      2
# 89      2
# 192     2
# 197     2
# 158     2
# 81      2
# 188     2
# 194     2
# 153     2
# 129     2
# 108     2
# 110     2
# 164     2
# 145     2
# 113     2
# 256     1
# 107     1
# 90      1
# 231     1
# 142     1
# 121     1
# 78      1
# 98      1
# 186     1
# 77      1
# Name: count, dtype: int64

# %%
#in all df  it is replaced
df.replace('?',np.nan,inplace=True)

# %%
# to find null values
df['normalized-losses'].isna().sum()
# Out:
# 41

# %%
# to replace null value we have to change it into float replaced by median so
df['normalized-losses']=df['normalized-losses'].astype(float)

# %%
df['normalized-losses'].fillna(df['normalized-losses'].median(),inplace=True)

# %%
df['normalized-losses'].isna().sum()
# Out:
# 0

# %% [markdown]
# ## num-of-doors

# %%
df['num-of-doors'].value_counts()
# Out:
# num-of-doors
# four    114
# two      89
# Name: count, dtype: int64

# %%
df['num-of-doors'].fillna('four',inplace=True)

# %%
df['num-of-doors'].isna().sum()
# Out:
# 0

# %% [markdown]
# ## bore

# %%
df['bore'].value_counts()
# Out:
# bore
# 3.62    23
# 3.19    20
# 3.15    15
# 3.03    12
# 2.97    12
# 3.46     9
# 3.78     8
# 3.31     8
# 3.43     8
# 3.27     7
# 2.91     7
# 3.54     6
# 3.05     6
# 3.58     6
# 3.39     6
# 3.01     5
# 3.7      5
# 3.35     4
# 3.17     3
# 3.59     3
# 3.74     3
# 3.33     2
# 3.24     2
# 3.94     2
# 3.47     2
# 3.8      2
# 3.63     2
# 3.5      2
# 3.13     2
# 2.68     1
# 2.99     1
# 3.08     1
# 3.61     1
# 2.92     1
# 3.6      1
# 2.54     1
# 3.34     1
# 3.76     1
# Name: count, dtype: int64

# %%
df['bore'].isna().sum()
# Out:
# 4

# %%
df['bore']=df['bore'].astype(float)

# %%
df['bore'].fillna(df['bore'].median(),inplace=True)

# %%
df['bore'].isna().sum()
# Out:
# 0

# %% [markdown]
# ## stroke

# %%
df['stroke'].value_counts()
# Out:
# stroke
# 3.4     20
# 3.03    14
# 3.23    14
# 3.15    14
# 3.39    13
# 2.64    11
# 3.29     9
# 3.35     9
# 3.46     8
# 3.07     6
# 3.58     6
# 3.5      6
# 3.27     6
# 3.41     6
# 3.11     6
# 3.19     6
# 3.52     5
# 3.64     5
# 3.47     4
# 3.86     4
# 3.54     4
# 3.9      3
# 2.9      3
# 3.08     2
# 2.19     2
# 2.68     2
# 3.1      2
# 4.17     2
# 2.8      2
# 3.12     1
# 3.21     1
# 2.07     1
# 2.36     1
# 3.16     1
# 2.76     1
# 2.87     1
# Name: count, dtype: int64

# %%
df['stroke'].isna().sum()
# Out:
# 4

# %%
df['stroke']=df['stroke'].astype(float)

# %%
df['stroke'].fillna(df['stroke'].median(),inplace=True)

# %%
df['stroke'].isna().sum()
# Out:
# 0

# %% [markdown]
# ## horsepower

# %%
df['horsepower'].value_counts()
# Out:
# horsepower
# 68     19
# 70     11
# 69     10
# 116     9
# 110     8
# 95      7
# 114     6
# 160     6
# 101     6
# 62      6
# 88      6
# 145     5
# 76      5
# 97      5
# 82      5
# 84      5
# 102     5
# 92      4
# 111     4
# 123     4
# 86      4
# 207     3
# 182     3
# 90      3
# 121     3
# 152     3
# 85      3
# 73      3
# 161     2
# 94      2
# 56      2
# 112     2
# 184     2
# 155     2
# 156     2
# 52      2
# 100     2
# 162     2
# 176     2
# 140     1
# 115     1
# 134     1
# 78      1
# 48      1
# 288     1
# 143     1
# 142     1
# 200     1
# 58      1
# 55      1
# 60      1
# 175     1
# 154     1
# 72      1
# 120     1
# 64      1
# 135     1
# 262     1
# 106     1
# Name: count, dtype: int64

# %%
df['horsepower'].isna().sum()
# Out:
# 2

# %%
df['horsepower']=df['horsepower'].astype(float)

# %%
df['horsepower'].fillna(df['horsepower'].median(),inplace=True)

# %%
df['horsepower'].isna().sum()
# Out:
# 0

# %% [markdown]
# ## peak-rpm

# %%
df['peak-rpm'].value_counts()
# Out:
# peak-rpm
# 5500    37
# 4800    36
# 5000    27
# 5200    23
# 5400    13
# 6000     9
# 5800     7
# 5250     7
# 4500     7
# 4150     5
# 4200     5
# 4350     4
# 4750     4
# 5100     3
# 5900     3
# 4250     3
# 4400     3
# 6600     2
# 4650     1
# 5600     1
# 5750     1
# 4900     1
# 5300     1
# Name: count, dtype: int64

# %%
df['peak-rpm'].isna().sum()
# Out:
# 2

# %%
df['peak-rpm']=df['peak-rpm'].astype(float)

# %%
df['peak-rpm'].fillna(df['peak-rpm'].median(),inplace=True)

# %% [markdown]
# ## price

# %%
df['price'].value_counts()
# Out:
# price
# 8921     2
# 18150    2
# 8845     2
# 8495     2
# 7609     2
#         ..
# 45400    1
# 16503    1
# 5389     1
# 6189     1
# 22625    1
# Name: count, Length: 186, dtype: int64

# %%
df['price'].isna().sum()
# Out:
# 4

# %%
df['price']=df['price'].astype(float)

# %%
df['price'].fillna(df['price'].median(),inplace=True)

# %%
df['price'].isna().sum()
# Out:
# 0

# %% [markdown]
# # FIND OUT OUTLIERS
# # REMOVE THE OUTLIERS

# %%
a=df.describe().columns
a
# Out:
# Index(['symboling', 'normalized-losses', 'wheel-base', 'length', 'width',
#        'height', 'curb-weight', 'engine-size', 'bore', 'stroke',
#        'compression-ratio', 'horsepower', 'peak-rpm', 'city-mpg',
#        'highway-mpg', 'price'],
#       dtype='object')

# %%
for i in a:
    plt.figure()
    plt.boxplot(df[i])
    plt.title(i)
    plt.show()

    q1=df[i].quantile(0.25)
    q3=df[i].quantile(0.75)
    iqr=q3-q1
    upper_tail=q3+1.5*iqr
    lower_tail=q1-1.5*iqr

    print("q1--->",q1)
    print("q3--->",q3)
    print("iqr--->",iqr)
    print("upper_tail--->",upper_tail)
    print("lower_tail--->",lower_tail)
# Out:
# q1---> 0.0
# q3---> 2.0
# iqr---> 2.0
# upper_tail---> 5.0
# lower_tail---> -3.0
# q1---> 101.0
# q3---> 137.0
# iqr---> 36.0
# upper_tail---> 191.0
# lower_tail---> 47.0
# q1---> 94.5
# q3---> 102.4
# iqr---> 7.900000000000006
# upper_tail---> 114.25000000000001
# lower_tail---> 82.64999999999999
# q1---> 166.3
# q3---> 183.1
# iqr---> 16.799999999999983
# upper_tail---> 208.29999999999995
# lower_tail---> 141.10000000000002
# q1---> 64.1
# q3---> 66.9
# iqr---> 2.8000000000000114
# upper_tail---> 71.10000000000002
# lower_tail---> 59.89999999999998
# q1---> 52.0
# q3---> 55.5
# iqr---> 3.5
# upper_tail---> 60.75
# lower_tail---> 46.75
# q1---> 2145.0
# q3---> 2935.0
# iqr---> 790.0
# upper_tail---> 4120.0
# lower_tail---> 960.0
# q1---> 97.0
# q3---> 141.0
# iqr---> 44.0
# upper_tail---> 207.0
# lower_tail---> 31.0
# q1---> 3.15
# q3---> 3.58
# iqr---> 0.43000000000000016
# upper_tail---> 4.2250000000000005
# lower_tail---> 2.505
# q1---> 3.11
# q3---> 3.41
# ...

# %%
# only those who have outliers 
# but we have make seprate boxplot or show seprate outliers

# %%
    plt.figure()
    plt.boxplot(df['normalized-losses'])
    plt.title('normalized-losses')
    plt.show()

    q1=df['normalized-losses'].quantile(0.25)
    q3=df['normalized-losses'].quantile(0.75)
    iqr=q3-q1
    upper_tail=q3+1.5*iqr
    lower_tail=q1-1.5*iqr

    print("q1--->",q1)
    print("q3--->",q3)
    print("iqr--->",iqr)
    print("upper_tail--->",upper_tail)
    print("lower_tail--->",lower_tail)
# Out:
# q1---> 101.0
# q3---> 137.0
# iqr---> 36.0
# upper_tail---> 191.0
# lower_tail---> 47.0

# %%
df.loc[df['normalized-losses']>upper_tail,'normalized-losses']=upper_tail

# %%
    plt.figure()
    plt.boxplot(df['wheel-base'])
    plt.title('wheel-base')
    plt.show()

    q1=df['wheel-base'].quantile(0.25)
    q3=df['wheel-base'].quantile(0.75)
    iqr=q3-q1
    upper_tail=q3+1.5*iqr
    lower_tail=q1-1.5*iqr

    print("q1--->",q1)
    print("q3--->",q3)
    print("iqr--->",iqr)
    print("upper_tail--->",upper_tail)
    print("lower_tail--->",lower_tail)
# Out:
# q1---> 94.5
# q3---> 102.4
# iqr---> 7.900000000000006
# upper_tail---> 114.25000000000001
# lower_tail---> 82.64999999999999

# %%
df.loc[df['wheel-base']>upper_tail,'wheel-base']=upper_tail

# %%
    plt.figure()
    plt.boxplot(df['length'])
    plt.title('length')
    plt.show()

    q1=df['length'].quantile(0.25)
    q3=df['length'].quantile(0.75)
    iqr=q3-q1
    upper_tail=q3+1.5*iqr
    lower_tail=q1-1.5*iqr

    print("q1--->",q1)
    print("q3--->",q3)
    print("iqr--->",iqr)
    print("upper_tail--->",upper_tail)
    print("lower_tail--->",lower_tail)
# Out:
# q1---> 166.3
# q3---> 183.1
# iqr---> 16.799999999999983
# upper_tail---> 208.29999999999995
# lower_tail---> 141.10000000000002

# %%
df.loc[df['length']<lower_tail,'length']=lower_tail

# %%
    plt.figure()
    plt.boxplot(df['width'])
    plt.title('width')
    plt.show()

    q1=df['width'].quantile(0.25)
    q3=df['width'].quantile(0.75)
    iqr=q3-q1
    upper_tail=q3+1.5*iqr
    lower_tail=q1-1.5*iqr

    print("q1--->",q1)
    print("q3--->",q3)
    print("iqr--->",iqr)
    print("upper_tail--->",upper_tail)
    print("lower_tail--->",lower_tail)
# Out:
# q1---> 64.1
# q3---> 66.9
# iqr---> 2.8000000000000114
# upper_tail---> 71.10000000000002
# lower_tail---> 59.89999999999998

# %%
df.loc[df['width']>upper_tail,'width']=upper_tail

# %%
    plt.figure()
    plt.boxplot(df['engine-size'])
    plt.title('engine-size')
    plt.show()

    q1=df['engine-size'].quantile(0.25)
    q3=df['engine-size'].quantile(0.75)
    iqr=q3-q1
    upper_tail=q3+1.5*iqr
    lower_tail=q1-1.5*iqr

    print("q1--->",q1)
    print("q3--->",q3)
    print("iqr--->",iqr)
    print("upper_tail--->",upper_tail)
    print("lower_tail--->",lower_tail)
# Out:
# q1---> 97.0
# q3---> 141.0
# iqr---> 44.0
# upper_tail---> 207.0
# lower_tail---> 31.0

# %%
df.loc[df['engine-size']>upper_tail,'engine-size']=upper_tail

# %%
    plt.figure()
    plt.boxplot(df['stroke'])
    plt.title('stroke')
    plt.show()

    q1=df['stroke'].quantile(0.25)
    q3=df['stroke'].quantile(0.75)
    iqr=q3-q1
    upper_tail=q3+1.5*iqr
    lower_tail=q1-1.5*iqr

    print("q1--->",q1)
    print("q3--->",q3)
    print("iqr--->",iqr)
    print("upper_tail--->",upper_tail)
    print("lower_tail--->",lower_tail)
# Out:
# q1---> 3.11
# q3---> 3.41
# iqr---> 0.30000000000000027
# upper_tail---> 3.8600000000000003
# lower_tail---> 2.6599999999999993

# %%
df.loc[df['stroke']>upper_tail,'stroke']=upper_tail
df.loc[df['stroke']<lower_tail,'stroke']=lower_tail

# %%
    plt.figure()
    plt.boxplot(df['compression-ratio'])
    plt.title('compression-ratio')
    plt.show()

    q1=df['compression-ratio'].quantile(0.25)
    q3=df['compression-ratio'].quantile(0.75)
    iqr=q3-q1
    upper_tail=q3+1.5*iqr
    lower_tail=q1-1.5*iqr

    print("q1--->",q1)
    print("q3--->",q3)
    print("iqr--->",iqr)
    print("upper_tail--->",upper_tail)
    print("lower_tail--->",lower_tail)
# Out:
# q1---> 8.6
# q3---> 9.4
# iqr---> 0.8000000000000007
# upper_tail---> 10.600000000000001
# lower_tail---> 7.399999999999999

# %%
df.loc[df['compression-ratio']>upper_tail,'compression-ratio']=upper_tail
df.loc[df['compression-ratio']<lower_tail,'compression-ratio']=lower_tail

# %%
    plt.figure()
    plt.boxplot(df['horsepower'])
    plt.title('horsepower')
    plt.show()

    q1=df['horsepower'].quantile(0.25)
    q3=df['horsepower'].quantile(0.75)
    iqr=q3-q1
    upper_tail=q3+1.5*iqr
    lower_tail=q1-1.5*iqr

    print("q1--->",q1)
    print("q3--->",q3)
    print("iqr--->",iqr)
    print("upper_tail--->",upper_tail)
    print("lower_tail--->",lower_tail)
# Out:
# q1---> 70.0
# q3---> 116.0
# iqr---> 46.0
# upper_tail---> 185.0
# lower_tail---> 1.0

# %%
df.loc[df['horsepower']>upper_tail,'horsepower']=upper_tail

# %%
    plt.figure()
    plt.boxplot(df['peak-rpm'])
    plt.title('peak-rpm')
    plt.show()

    q1=df['peak-rpm'].quantile(0.25)
    q3=df['peak-rpm'].quantile(0.75)
    iqr=q3-q1
    upper_tail=q3+1.5*iqr
    lower_tail=q1-1.5*iqr

    print("q1--->",q1)
    print("q3--->",q3)
    print("iqr--->",iqr)
    print("upper_tail--->",upper_tail)
    print("lower_tail--->",lower_tail)
# Out:
# q1---> 4800.0
# q3---> 5500.0
# iqr---> 700.0
# upper_tail---> 6550.0
# lower_tail---> 3750.0

# %%
df.loc[df['peak-rpm']>upper_tail,'peak-rpm']=upper_tail

# %%
    plt.figure()
    plt.boxplot(df['city-mpg'])
    plt.title('city-mpg')
    plt.show()

    q1=df['city-mpg'].quantile(0.25)
    q3=df['city-mpg'].quantile(0.75)
    iqr=q3-q1
    upper_tail=q3+1.5*iqr
    lower_tail=q1-1.5*iqr

    print("q1--->",q1)
    print("q3--->",q3)
    print("iqr--->",iqr)
    print("upper_tail--->",upper_tail)
    print("lower_tail--->",lower_tail)
# Out:
# q1---> 19.0
# q3---> 30.0
# iqr---> 11.0
# upper_tail---> 46.5
# lower_tail---> 2.5

# %%
df.loc[df['city-mpg']>upper_tail,'city-mpg']=upper_tail

# %%
plt.figure()
plt.boxplot(df['highway-mpg'])
plt.title('highway-mpg')
plt.show()    
q1=df['highway-mpg'].quantile(0.25)
q3=df['highway-mpg'].quantile(0.75)
q2=df['highway-mpg'].quantile(0.50)
iqr=q3-q1
upper_tail=q3+1.5*iqr
lower_tail=q1-1.5*iqr
print("Q1=",q1)
print("Q2=",q2)
print("Q3=",q3)
print("IQR=",iqr)
print("Upper_Whisker=",upper_tail)
print("Lower_Whisker=",lower_tail)
# Out:
# Q1= 25.0
# Q2= 30.0
# Q3= 34.0
# IQR= 9.0
# Upper_Whisker= 47.5
# Lower_Whisker= 11.5

# %%
df.loc[df['highway-mpg']>upper_tail,'highway-mpg']=upper_tail
df.loc[df['highway-mpg']<lower_tail,'highway-mpg']=lower_tail

# %% [markdown]
# # FIND THE SKEW

# %%
from scipy.stats import skew

# %%
#skewness should be between -2 to 2
for i in a:
    print(i,skew(df[i]))
# Out:
# symboling 0.20952469094997359
# normalized-losses 0.5920727153156412
# wheel-base 0.9181346151833728
# length 0.1548103188545354
# width 0.7705860182956094
# height 0.06265991683394276
# curb-weight 0.676402180083416
# engine-size 0.9017925370961177
# bore 0.02433083552118313
# stroke -0.38364250353006496
# compression-ratio 0.03489137453557325
# horsepower 0.8061893243623318
# peak-rpm 0.04342357027736441
# city-mpg 0.6001606305926463
# highway-mpg 0.3448936458830095
# price 1.8274812554683892

# %% [markdown]
# # Lableencoding

# %%
from sklearn.preprocessing import LabelEncoder

# %%
b=LabelEncoder()

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 205 entries, 0 to 204
# Data columns (total 26 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   symboling          205 non-null    int64
#  1   normalized-losses  205 non-null    float64
#  2   make               205 non-null    object
#  3   fuel-type          205 non-null    object
#  4   aspiration         205 non-null    object
#  5   num-of-doors       205 non-null    object
#  6   body-style         205 non-null    object
#  7   drive-wheels       205 non-null    object
#  8   engine-location    205 non-null    object
#  9   wheel-base         205 non-null    float64
#  10  length             205 non-null    float64
#  11  width              205 non-null    float64
#  12  height             205 non-null    float64
#  13  curb-weight        205 non-null    int64
#  14  engine-type        205 non-null    object
#  15  num-of-cylinders   205 non-null    object
# ...

# %% [markdown]
# ## convert all obj inot int

# %%
df['make']=b.fit_transform(df['make'])
df['fuel-type']=b.fit_transform(df['fuel-type'])
df['aspiration']=b.fit_transform(df['aspiration'])
df['num-of-doors']=b.fit_transform(df['num-of-doors'])
df['body-style']=b.fit_transform(df['body-style'])
df['drive-wheels']=b.fit_transform(df['drive-wheels'])
df['engine-location']=b.fit_transform(df['engine-location'])
df['engine-type']=b.fit_transform(df['engine-type'])
df['num-of-cylinders']=b.fit_transform(df['num-of-cylinders'])
df['fuel-system']=b.fit_transform(df['fuel-system'])

# %% [markdown]
# # scales down by minmaxscaler

# %%
#by minmax it becomes in float-- it scales down the into fixed range where
#largest occuuinr  data point corresponds to maximun smallest into minimum
from sklearn.preprocessing import MinMaxScaler

# %%
e=MinMaxScaler()

# %%
df['symboling']=e.fit_transform(df[['symboling']])
df['normalized-losses']=e.fit_transform(df[['normalized-losses']])
df['make']=e.fit_transform(df[['make']])
df['fuel-type']=e.fit_transform(df[['fuel-type']])
df['aspiration']=e.fit_transform(df[['aspiration']])
df['num-of-doors']=e.fit_transform(df[['num-of-doors']])
df['body-style']=e.fit_transform(df[['body-style']])
df['drive-wheels']=e.fit_transform(df[['drive-wheels']])
df['engine-location']=e.fit_transform(df[['engine-location']])
df['wheel-base']=e.fit_transform(df[['wheel-base']])
df['length']=e.fit_transform(df[['length']])
df['width']=e.fit_transform(df[['width']])
df['height']=e.fit_transform(df[['height']])
df['curb-weight']=e.fit_transform(df[['curb-weight']])
df['engine-type']=e.fit_transform(df[['engine-type']])
df['num-of-cylinders']=e.fit_transform(df[['num-of-cylinders']])
df['engine-size']=e.fit_transform(df[['engine-size']])
df['fuel-system']=e.fit_transform(df[['fuel-system']])
df['bore']=e.fit_transform(df[['bore']])
df['stroke']=e.fit_transform(df[['stroke']])
df['compression-ratio']=e.fit_transform(df[['compression-ratio']])
df['horsepower']=e.fit_transform(df[['horsepower']])
df['peak-rpm']=e.fit_transform(df[['peak-rpm']])
df['city-mpg']=e.fit_transform(df[['city-mpg']])
df['highway-mpg']=e.fit_transform(df[['highway-mpg']])
df['price']=e.fit_transform(df[['price']])

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 205 entries, 0 to 204
# Data columns (total 26 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   symboling          205 non-null    float64
#  1   normalized-losses  205 non-null    float64
#  2   make               205 non-null    float64
#  3   fuel-type          205 non-null    float64
#  4   aspiration         205 non-null    float64
#  5   num-of-doors       205 non-null    float64
#  6   body-style         205 non-null    float64
#  7   drive-wheels       205 non-null    float64
#  8   engine-location    205 non-null    float64
#  9   wheel-base         205 non-null    float64
#  10  length             205 non-null    float64
#  11  width              205 non-null    float64
#  12  height             205 non-null    float64
#  13  curb-weight        205 non-null    float64
#  14  engine-type        205 non-null    float64
# ...

# %%
d=df.columns
d
# Out:
# Index(['symboling', 'normalized-losses', 'make', 'fuel-type', 'aspiration',
#        'num-of-doors', 'body-style', 'drive-wheels', 'engine-location',
#        'wheel-base', 'length', 'width', 'height', 'curb-weight', 'engine-type',
#        'num-of-cylinders', 'engine-size', 'fuel-system', 'bore', 'stroke',
#        'compression-ratio', 'horsepower', 'peak-rpm', 'city-mpg',
#        'highway-mpg', 'price'],
#       dtype='object')

# %%
'''df['engine-location']=np.sqrt(df['engine-location'])
skew(df['engine-location'])'''
# Out:
# "df['engine-location']=np.sqrt(df['engine-location'])\nskew(df['engine-location'])"

# %%
for i in d:
    print(i,skew(df[i]))
# Out:
# symboling 0.20952469094997275
# normalized-losses 0.5920727153156393
# make -0.24287751005553573
# fuel-type -2.712583290538397
# aspiration 1.6615590978892794
# num-of-doors 0.2657294974728979
# body-style -0.6604229011586394
# drive-wheels -0.05792444798139604
# engine-location 8.083822413838753
# wheel-base 0.9181346151833765
# length 0.15481031885452365
# width 0.770586018295594
# height 0.06265991683394519
# curb-weight 0.6764021800834155
# engine-type -0.5316755503859274
# num-of-cylinders 2.128530896441381
# engine-size 0.9017925370961184
# fuel-system -0.24121332186599292
# bore 0.024330835521177385
# stroke -0.38364250353006796
# compression-ratio 0.034891374535571146
# horsepower 0.8061893243623321
# peak-rpm 0.04342357027736706
# city-mpg 0.6001606305926455
# highway-mpg 0.3448936458830099
# price 1.8274812554683901

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 205 entries, 0 to 204
# Data columns (total 26 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   symboling          205 non-null    float64
#  1   normalized-losses  205 non-null    float64
#  2   make               205 non-null    float64
#  3   fuel-type          205 non-null    float64
#  4   aspiration         205 non-null    float64
#  5   num-of-doors       205 non-null    float64
#  6   body-style         205 non-null    float64
#  7   drive-wheels       205 non-null    float64
#  8   engine-location    205 non-null    float64
#  9   wheel-base         205 non-null    float64
#  10  length             205 non-null    float64
#  11  width              205 non-null    float64
#  12  height             205 non-null    float64
#  13  curb-weight        205 non-null    float64
#  14  engine-type        205 non-null    float64
# ...

# %%
df.corr()
# Out:
#                    symboling  normalized-losses      make  fuel-type  \
# symboling           1.000000           0.461559 -0.118794   0.194311
# normalized-losses   0.461559           1.000000 -0.260517   0.104505
# make               -0.118794          -0.260517  1.000000  -0.113191
# fuel-type           0.194311           0.104505 -0.113191   1.000000
# aspiration         -0.059866          -0.003670  0.054265  -0.401397
# num-of-doors        0.663595           0.347699 -0.151516   0.188496
# body-style         -0.596135          -0.245685  0.089494  -0.147853
# drive-wheels       -0.041671           0.299660 -0.004317  -0.132257
# engine-location     0.212471          -0.020367  0.054608   0.040070
# wheel-base         -0.537515          -0.071115  0.084330  -0.314415
# length             -0.357612          -0.003735  0.119584  -0.212679
# width              -0.235697           0.065801  0.009647  -0.239809
# height             -0.541038          -0.364713  0.236233  -0.284631
# ...

# %%
plt.figure()
sns.heatmap(df.corr(),cmap='coolwarm')
# Out:
# <Axes: >

# %% [markdown]
# ## split train test

# %%
from sklearn.model_selection import train_test_split

# %%
x=df.drop('price',axis=1)
y=df['price']

# %%
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.2,random_state=2)

# %%
x_train
# Out:
#      symboling  normalized-losses      make  fuel-type  aspiration  \
# 71         0.2           0.396825  0.428571        1.0         0.0
# 9          0.4           0.396825  0.047619        1.0         1.0
# 118        0.6           0.428571  0.666667        1.0         0.0
# 174        0.2           0.000000  0.904762        0.0         1.0
# 146        0.4           0.190476  0.857143        1.0         0.0
# ..         ...                ...       ...        ...         ...
# 43         0.4           0.396825  0.285714        1.0         0.0
# 22         0.6           0.420635  0.190476        1.0         0.0
# 72         1.0           0.611111  0.428571        1.0         0.0
# 15         0.4           0.396825  0.095238        1.0         0.0
# 168        0.8           0.547619  0.904762        1.0         0.0
#
#      num-of-doors  body-style  drive-wheels  engine-location  wheel-base  ...  \
# 71            0.0        0.75           1.0              0.0    1.000000  ...
# ...

# %%
x_test
# Out:
#      symboling  normalized-losses      make  fuel-type  aspiration  \
# 25         0.6           0.658730  0.190476        1.0         0.0
# 84         1.0           0.396825  0.523810        1.0         1.0
# 100        0.4           0.325397  0.571429        1.0         0.0
# 10         0.8           1.000000  0.095238        1.0         0.0
# 195        0.2           0.071429  1.000000        1.0         0.0
# 53         0.6           0.380952  0.380952        1.0         0.0
# 65         0.4           0.420635  0.380952        1.0         0.0
# 66         0.4           0.396825  0.380952        0.0         0.0
# 182        0.8           0.452381  0.952381        0.0         0.0
# 175        0.2           0.000000  0.904762        1.0         0.0
# 29         1.0           0.634921  0.190476        1.0         1.0
# 153        0.4           0.095238  0.904762        1.0         0.0
# 183        0.8           0.452381  0.952381        1.0         0.0
# ...

# %%
y_train
# Out:
# 71     0.721563
# 9      0.128519
# 118    0.011271
# 174    0.138523
# 146    0.058215
#          ...
# 43     0.041383
# 22     0.031255
# 72     0.743210
# 15     0.636562
# 168    0.112234
# Name: price, Length: 164, dtype: float64

# %%
y_test
# Out:
# 25     0.039075
# 84     0.232635
# 100    0.110000
# 10     0.280820
# 195    0.205973
# 53     0.039149
# 65     0.326746
# 66     0.328335
# 182    0.065960
# 175    0.120898
# 29     0.194777
# 153    0.044685
# 183    0.070925
# 13     0.396877
# 134    0.246313
# 94     0.054143
# 164    0.077454
# 35     0.054044
# 127    0.717690
# 24     0.027581
# 23     0.070478
# 45     0.128519
# 6      0.312596
# 12     0.393526
# 64     0.152103
# 18     0.000819
# 157    0.051636
# 173    0.095080
# 172    0.311578
# 2      0.282558
# 57     0.211683
# 3      0.219254
# 120    0.027581
# 14     0.482771
# 44     0.128519
# 178    0.283998
# 113    0.287399
# 179    0.270096
# 192    0.216648
# 184    0.071421
# 111    0.259719
# Name: price, dtype: float64

# %%
from sklearn.linear_model import LinearRegression

# %%
lr=LinearRegression()

# %%
lr_model=lr.fit(x_train,y_train)

# %%
lr_model.coef_
# Out:
# array([ 0.11146942, -0.06668829, -0.07429505, -0.0926103 , -0.04293756,
#        -0.02664607, -0.11053169,  0.07379445,  0.32942431,  0.13080143,
#         0.2329466 ,  0.12374781, -0.00184191,  0.279018  ,  0.08170871,
#        -0.00844622,  0.15886166, -0.05440849, -0.16800973, -0.13326272,
#        -0.11284225,  0.22900097,  0.07562912,  0.43676008, -0.27782375])

# %%
lr_model.intercept_
# Out:
# -0.03734466570570388

# %%
y_pred=lr_model.predict(x_test)
y_pred
# Out:
# array([ 0.00965841,  0.23989225,  0.11978753,  0.2181233 ,  0.25421212,
#         0.04462784,  0.23736752,  0.18361227,  0.05524338,  0.11787929,
#         0.25067782,  0.03033794,  0.03413957,  0.24111005,  0.38461843,
#        -0.02742749,  0.06167104,  0.09794159,  0.72011149,  0.03491026,
#         0.05084584,  0.03193616,  0.4059341 ,  0.20851132,  0.17836127,
#        -0.07519969,  0.0480612 ,  0.08900423,  0.25721215,  0.40257596,
#         0.16886201,  0.1539249 , -0.00364396,  0.42399415,  0.02379592,
#         0.39725703,  0.43999991,  0.38854864,  0.12853655,  0.09703376,
#         0.34833793])

# %%
lr_model.score(x_train,y_train)
# Out:
# 0.8676791110521214

# %%
lr_model.score(x_test,y_test)
# Out:
# 0.7072562013250989

# %%
residual=y_test-y_pred
residual
# Out:
# 25     0.029416
# 84    -0.007257
# 100   -0.009788
# 10     0.062697
# 195   -0.048239
# 53    -0.005479
# 65     0.089379
# 66     0.144723
# 182    0.010717
# 175    0.003018
# 29    -0.055901
# 153    0.014347
# 183    0.036785
# 13     0.155767
# 134   -0.138305
# 94     0.081571
# 164    0.015783
# 35    -0.043898
# 127   -0.002421
# 24    -0.007330
# 23     0.019632
# 45     0.096583
# 6     -0.093338
# 12     0.185014
# 64    -0.026259
# 18     0.076019
# 157    0.003575
# 173    0.006075
# 172    0.054366
# 2     -0.120018
# 57     0.042821
# 3      0.065329
# 120    0.031225
# 14     0.058777
# 44     0.104723
# 178   -0.113259
# 113   -0.152601
# 179   -0.118453
# 192    0.088111
# 184   -0.025612
# 111   -0.088619
# Name: price, dtype: float64

# %%
sns.distplot(residual)
# Out:
# <Axes: xlabel='price', ylabel='Density'>

# %%
plt.scatter(y_pred,residual)
plt.show()

# %%
from sklearn.metrics import mean_squared_error,mean_absolute_error,r2_score

# %% [markdown]
# ## Training

# %%
y_pred_train=lr_model.predict(x_train)
mse_train=mean_squared_error(y_train,y_pred_train)
mae_train=mean_absolute_error(y_train,y_pred_train)
r2_train=r2_score(y_train,y_pred_train)
print("mse_train-->",mse_train)
print("mae_train-->",mae_train)
print("r2_score-->",r2_train)
# Out:
# mse_train--> 0.0055847787954113465
# mae_train--> 0.05352397236156195
# r2_score--> 0.8676791110521214

# %% [markdown]
# ## Testing

# %%
y_pred_test=lr_model.predict(x_test)
mse_test=mean_squared_error(y_test,y_pred_test)
mae_test=mean_absolute_error(y_test,y_pred_test)
r2_test=r2_score(y_test,y_pred_test)
print("mse_test-->",mse_test)
print("mae_test-->",mae_test)
print("r2_score-->",r2_test)
# Out:
# mse_test--> 0.006287192391567129
# mae_test--> 0.06178610666787301
# r2_score--> 0.7072562013250989

# %% [markdown]
# # Regularization

# %%
from sklearn.linear_model import Ridge

# %%
l2=Ridge(0.02)

# %%
l2.fit(x_train,y_train)
# Out:
# Ridge(alpha=0.02)

# %%
l2.score(x_train,y_train)
# Out:
# 0.8675778077404734

# %%
l2.score(x_test,y_test)
# Out:
# 0.7147182653114549
